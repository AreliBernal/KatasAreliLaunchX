# %% [markdown]
#             Kata 1

# %%
from datetime import date
date.today()
print("La fecha de hoy es "+str(date.today()))
# Out:
# La fecha de hoy es 2022-02-06

# %%
parsec = 11
lightyears= parsec*3.26156
print (str (parsec) +"años parsec son " + str (lightyears) +" años luz")
# Out:
# 11años parsec son 35.877159999999996 años luz
